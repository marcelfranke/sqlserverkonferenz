# %%
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-train-tensorflow

# %% [markdown]
# ## Import packages

# %%
import os
import urllib
import shutil
import azureml

from azureml.core import Experiment
from azureml.core import Workspace, Run

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.train.dnn import TensorFlow

# %% [markdown]
# # Initialize a workspace

# %%
ws = Workspace.from_config()

# %%
ws.get_details()
# Out:
# {'id': '/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourceGroups/SQLServerKonferenz2020/providers/Microsoft.MachineLearningServices/workspaces/MLDemo',
#  'name': 'MLDemo',
#  'location': 'northeurope',
#  'type': 'Microsoft.MachineLearningServices/workspaces',
#  'tags': {},
#  'sku': 'Enterprise',
#  'workspaceid': '33f5cdb9-d04e-4f11-bb7a-263b2736aab0',
#  'description': '',
#  'friendlyName': '',
#  'creationTime': '2020-02-18T12:30:56.1352089+00:00',
#  'containerRegistry': '/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourceGroups/SQLServerKonferenz2020/providers/Microsoft.ContainerRegistry/registries/mldemof2348786',
#  'keyVault': '/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourcegroups/sqlserverkonferenz2020/providers/microsoft.keyvault/vaults/mldemo9819592044',
#  'applicationInsights': '/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourcegroups/sqlserverkonferenz2020/providers/microsoft.insights/components/mldemo2790914701',
#  'identityPrincipalId': 'c7f84daa-3a85-4927-86a6-bce45e7cccd0',
#  'identityTenantId': '72f988bf-86f1-41af-91ab-2d7cd011db47',
#  'identityType': 'SystemAssigned',
#  'storageAccount': '/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourcegroups/sqlserverkonferenz2020/providers/microsoft.storage/storageaccounts/mldemo9068087925',
#  'hbiWorkspace': False}

# %% [markdown]
# ## Create a deep learning experiment

# %%
script_folder = './tf-mnist'
os.makedirs(script_folder, exist_ok=True)

exp = Experiment(workspace=ws, name='tf-mnist')

# %% [markdown]
# ## Create a file dataset

# %%
from azureml.core.dataset import Dataset

web_paths = [
            'http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz',
            'http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz',
            'http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz',
            'http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz'
            ]
dataset = Dataset.File.from_files(path=web_paths)

# %%
dataset = dataset.register(workspace=ws,
                           name='mnist dataset',
                           description='training and test dataset',
                           create_new_version=True)

# list the files referenced by dataset
dataset.to_path()
# Out:
# array(['/http/yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz',
#        '/http/yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz',
#        '/http/yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz',
#        '/http/yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz'],
#       dtype=object)

# %% [markdown]
# ## Create a compute target

# %%
cluster_name = "gpucluster"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_NC6', 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Found existing compute target

# %% [markdown]
# ## Create a TensorFlow estimator

# %%
script_params = {
    '--data-folder': dataset.as_named_input('mnist').as_mount(),
    '--batch-size': 50,
    '--first-layer-neurons': 300,
    '--second-layer-neurons': 100,
    '--learning-rate': 0.01
}

est = TensorFlow(source_directory=script_folder,
                 entry_script='tf_mnist.py',
                 script_params=script_params,
                 compute_target=compute_target,
                 use_gpu=True,
                 pip_packages=['azureml-dataprep[pandas,fuse]'])
# Out:
# WARNING - framework_version is not specified, defaulting to version 1.13.

# %% [markdown]
# ## Submit a run

# %%
run = exp.submit(est)
run.wait_for_completion(show_output=True)
# Out:
# RunId: tf-mnist_1583168288_485f9fd8
# Web View: https://ml.azure.com/experiments/tf-mnist/runs/tf-mnist_1583168288_485f9fd8?wsid=/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourcegroups/sqlserverkonferenz2020/workspaces/mldemo
#
# Streaming azureml-logs/55_azureml-execution-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt
# ========================================================================================================================
#
# 2020-03-02T17:00:56Z Starting output-watcher...
# 2020-03-02T17:00:56Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_1d5e282518217ede461ec1726f1f4557
# f7277927d38a: Pulling fs layer
# 8d3eac894db4: Pulling fs layer
# edf72af6d627: Pulling fs layer
# 3e4f86211d23: Pulling fs layer
# d6e9603ff777: Pulling fs layer
# 5cad422780e2: Pulling fs layer
# 8130687c8acb: Pulling fs layer
# c11e9246d621: Pulling fs layer
# 0dfae24cbbd9: Pulling fs layer
# 0bb049a6d391: Pulling fs layer
# 22a53069998a: Pulling fs layer
# db550b9db251: Pulling fs layer
# 10a826755d7e: Pulling fs layer
# 3e4f86211d23: Waiting
# 457c96476eac: Pulling fs layer
# d6e9603ff777: Waiting
# e2d7418d62ad: Pulling fs layer
# 8130687c8acb: Waiting
# a0d6fa61e0b7: Pulling fs layer
# 93f75153ba2d: Pulling fs layer
# c11e9246d621: Waiting
# 435aa96ed16e: Pulling fs layer
# d360acd15cf6: Pulling fs layer
# b9d304610f0f: Pulling fs layer
# 51d07a5ef961: Pulling fs layer
# a4f78ec21a8d: Pulling fs layer
# f366159de4d2: Pulling fs layer
# 0dfae24cbbd9: Waiting
# 0bb049a6d391: Waiting
# 22a53069998a: Waiting
# 5cad422780e2: Waiting
# 435aa96ed16e: Waiting
# db550b9db251: Waiting
# d360acd15cf6: Waiting
# 10a826755d7e: Waiting
# b9d304610f0f: Waiting
# 457c96476eac: Waiting
# 51d07a5ef961: Waiting
# e2d7418d62ad: Waiting
# 93f75153ba2d: Waiting
# a4f78ec21a8d: Waiting
# f366159de4d2: Waiting
# a0d6fa61e0b7: Waiting
# edf72af6d627: Verifying Checksum
# edf72af6d627: Download complete
# 8d3eac894db4: Verifying Checksum
# 8d3eac894db4: Download complete
# f7277927d38a: Verifying Checksum
# f7277927d38a: Download complete
# 3e4f86211d23: Download complete
# d6e9603ff777: Download complete
# 8130687c8acb: Verifying Checksum
# 8130687c8acb: Download complete
# 5cad422780e2: Download complete
# f7277927d38a: Pull complete
# 8d3eac894db4: Pull complete
# edf72af6d627: Pull complete
# 3e4f86211d23: Pull complete
# d6e9603ff777: Pull complete
# c11e9246d621: Verifying Checksum
# c11e9246d621: Download complete
# 5cad422780e2: Pull complete
# 8130687c8acb: Pull complete
# 0bb049a6d391: Verifying Checksum
# 0bb049a6d391: Download complete
# 22a53069998a: Verifying Checksum
# 22a53069998a: Download complete
# db550b9db251: Verifying Checksum
# db550b9db251: Download complete
# 10a826755d7e: Verifying Checksum
# 10a826755d7e: Download complete
# 457c96476eac: Verifying Checksum
# 457c96476eac: Download complete
# 0dfae24cbbd9: Verifying Checksum
# 0dfae24cbbd9: Download complete
# a0d6fa61e0b7: Verifying Checksum
# a0d6fa61e0b7: Download complete
# e2d7418d62ad: Verifying Checksum
# e2d7418d62ad: Download complete
# d360acd15cf6: Download complete
# 435aa96ed16e: Verifying Checksum
# 435aa96ed16e: Download complete
# 93f75153ba2d: Verifying Checksum
# 93f75153ba2d: Download complete
# b9d304610f0f: Download complete
# 51d07a5ef961: Download complete
# f366159de4d2: Verifying Checksum
# f366159de4d2: Download complete
# a4f78ec21a8d: Verifying Checksum
# a4f78ec21a8d: Download complete
# c11e9246d621: Pull complete
# 0dfae24cbbd9: Pull complete
# 0bb049a6d391: Pull complete
# 22a53069998a: Pull complete
# db550b9db251: Pull complete
# 10a826755d7e: Pull complete
# 457c96476eac: Pull complete
# e2d7418d62ad: Pull complete
# a0d6fa61e0b7: Pull complete
# 93f75153ba2d: Pull complete
# 435aa96ed16e: Pull complete
# d360acd15cf6: Pull complete
# b9d304610f0f: Pull complete
# 51d07a5ef961: Pull complete
# a4f78ec21a8d: Pull complete
# f366159de4d2: Pull complete
# Digest: sha256:19c43b1b0c0df66a2fb718639cd751574b692778857b584f5fa65b46f6278175
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_1d5e282518217ede461ec1726f1f4557:latest
#
# Streaming azureml-logs/65_job_prep-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job preparation. Current time:2020-03-02T17:02:49.452783
# Extracting the control code.
# Creating directory: azureml-logs/
# Retrieving project from snapshot: fd9a5032-0e4e-4753-b4a7-eddebabfb208
# Starting the daemon thread to refresh tokens in background for process with pid = 84
# Starting project file download.
# Finished project file download.
# Download from datastores if requested.
# Download or mount from datasets if requested.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# bash: /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/libtinfo.so.5: no version information available (required by bash)
# Initialize DatasetContextManager.
# Starting the daemon thread to refresh tokens in background for process with pid = 138
# Set Dataset mnist's target path to /tmp/tmpg3x8xdcx
# Enter __enter__ of DatasetContextManager
# Processing 'mnist'
# Processing dataset FileDataset
# {
#   "source": [
#     "http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz",
#     "http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz",
#     "http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz",
#     "http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "c1dc2de4-45ab-4877-add2-fa43e8cd8db5",
#     "name": "mnist dataset",
#     "version": 1,
#     "description": "training and test dataset",
#     "workspace": "Workspace.create(name='mldemo', subscription_id='b208dd3b-2592-4e14-a626-cd6941369193', resource_group='sqlserverkonferenz2020')"
#   }
# }
# Mounting mnist to /tmp/tmpg3x8xdcx
# Mounted mnist to /tmp/tmpg3x8xdcx
# Exit __enter__ of DatasetContextManager
# Entering Run History Context Manager.
# Preparing to call script [ tf_mnist.py ] with arguments: ['--data-folder', '$mnist', '--batch-size', '50', '--first-layer-neurons', '300', '--second-layer-neurons', '100', '--learning-rate', '0.01']
# After variable expansion, calling script [ tf_mnist.py ] with arguments: ['--data-folder', '/tmp/tmpg3x8xdcx', '--batch-size', '50', '--first-layer-neurons', '300', '--second-layer-neurons', '100', '--learning-rate', '0.01']
#
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# TensorFlow version: 1.13.1
# Data folder: /tmp/tmpg3x8xdcx
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)
# WARNING - From tf_mnist.py:55: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING - From /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2020-03-02 17:03:16.770169: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-03-02 17:03:17.010751: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x4b07120 executing computations on platform CUDA. Devices:
# 2020-03-02 17:03:17.010836: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-03-02 17:03:17.013644: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2596990000 Hz
# 2020-03-02 17:03:17.014032: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x4c221d0 executing computations on platform Host. Devices:
# 2020-03-02 17:03:17.014090: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-03-02 17:03:17.014723: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 266f:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.11GiB
# 2020-03-02 17:03:17.014859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-03-02 17:03:17.017777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-02 17:03:17.017842: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-03-02 17:03:17.017887: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-03-02 17:03:17.017979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10804 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 266f:00:00.0, compute capability: 3.7)
# 2020-03-02 17:03:17.650424: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# 0 -- Training accuracy: 0.9 Validation accuracy: 0.9066
# 1 -- Training accuracy: 0.8 Validation accuracy: 0.9221
# 2 -- Training accuracy: 0.86 Validation accuracy: 0.9333
# 3 -- Training accuracy: 0.98 Validation accuracy: 0.9374
# 4 -- Training accuracy: 0.96 Validation accuracy: 0.945
# 5 -- Training accuracy: 0.9 Validation accuracy: 0.9465
# 6 -- Training accuracy: 0.98 Validation accuracy: 0.9537
# 7 -- Training accuracy: 0.94 Validation accuracy: 0.9561
# 8 -- Training accuracy: 1.0 Validation accuracy: 0.9582
# 9 -- Training accuracy: 0.98 Validation accuracy: 0.9614
# 10 -- Training accuracy: 0.96 Validation accuracy: 0.9626
# 11 -- Training accuracy: 0.96 Validation accuracy: 0.9645
# 12 -- Training accuracy: 1.0 Validation accuracy: 0.9665
# 13 -- Training accuracy: 0.96 Validation accuracy: 0.9677
# 14 -- Training accuracy: 0.98 Validation accuracy: 0.9686
# 15 -- Training accuracy: 1.0 Validation accuracy: 0.9706
# 16 -- Training accuracy: 0.98 Validation accuracy: 0.9718
# 17 -- Training accuracy: 1.0 Validation accuracy: 0.9721
# 18 -- Training accuracy: 0.98 Validation accuracy: 0.9723
# 19 -- Training accuracy: 1.0 Validation accuracy: 0.9729
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.2667694091796875 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 138
# Enter __exit__ of DatasetContextManager
# Unmounting /tmp/tmpg3x8xdcx.
# Finishing unmounting /tmp/tmpg3x8xdcx.
# Exit __exit__ of DatasetContextManager
#
# Streaming azureml-logs/75_job_post-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job release. Current time:2020-03-02T17:03:58.697718
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 446
# Job release is complete. Current time:2020-03-02T17:04:01.120025
#
# Execution Summary
# =================
# RunId: tf-mnist_1583168288_485f9fd8
# Web View: https://ml.azure.com/experiments/tf-mnist/runs/tf-mnist_1583168288_485f9fd8?wsid=/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourcegroups/sqlserverkonferenz2020/workspaces/mldemo
# {'runId': 'tf-mnist_1583168288_485f9fd8',
#  'target': 'gpucluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-03-02T17:00:57.507434Z',
#  'endTimeUtc': '2020-03-02T17:04:15.179828Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'fe26bcec-e9a8-496a-a0e2-093c947ecb55',
#   'azureml.git.repository_uri': 'https://github.com/marcelfranke/sqlserverkonferenz.git',
#   'mlflow.source.git.repoURL': 'https://github.com/marcelfranke/sqlserverkonferenz.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': 'cd62b64c4786bfdafcce452be272413cf5cc82d7',
#   'mlflow.source.git.commit': 'cd62b64c4786bfdafcce452be272413cf5cc82d7',
#   'azureml.git.dirty': 'False',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': 'c1dc2de4-45ab-4877-add2-fa43e8cd8db5'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'mnist', 'mechanism': 'Mount'}}],
#  'runDefinition': {'script': 'tf_mnist.py',
#   'useAbsolutePath': False,
#   'arguments': ['--data-folder',
#    'DatasetConsumptionConfig:mnist',
#    '--batch-size',
#    '50',
#    '--first-layer-neurons',
#    '300',
#    '--second-layer-neurons',
#    '100',
#    '--learning-rate',
#    '0.01'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'gpucluster',
#   'dataReferences': {},
#   'data': {'mnist': {'dataLocation': {'dataset': {'id': 'c1dc2de4-45ab-4877-add2-fa43e8cd8db5'},
#      'dataPath': None},
#     'createOutputDirectories': False,
#     'mechanism': 'Mount',
#     'environmentVariableName': 'mnist',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'environment': {'name': 'Experiment tf-mnist Environment',
#    'version': 'Autosave_2020-03-01T20:24:31Z_26d07de6',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-dataprep[pandas,fuse]',
#         'azureml-defaults',
#         'tensorflow-gpu==1.13.1',
#         'horovod==0.16.1']}],
#      'name': 'azureml_87bf8b18f50c3819153ad5fad9efbcd9'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/base-gpu:intelmpi2018.3-cuda10.0-cudnn7-ubuntu16.04',
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': False},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': 1},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168288_485f9fd8/azureml-logs/55_azureml-execution-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt?sv=2019-02-02&sr=b&sig=7V3x904yncmTVDclItoFUkfCnBoE4X2yNo6ZZYAMGgE%3D&st=2020-03-02T16%3A54%3A15Z&se=2020-03-03T01%3A04%3A15Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168288_485f9fd8/azureml-logs/65_job_prep-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt?sv=2019-02-02&sr=b&sig=1nCsx9%2FHv4l0LxlvMyQXu0oI72fIZxLBtTnZTIjhqgk%3D&st=2020-03-02T16%3A54%3A16Z&se=2020-03-03T01%3A04%3A16Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168288_485f9fd8/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=eIuv9yL2wi94ihVwIB2LL%2BHbxbOzlZZ4%2Bv8h%2Ft3mUGQ%3D&st=2020-03-02T16%3A54%3A16Z&se=2020-03-03T01%3A04%3A16Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168288_485f9fd8/azureml-logs/75_job_post-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt?sv=2019-02-02&sr=b&sig=uichmwtA1tFA0pnfgTzTHG1Ibma0KDjEMMJwzGmWu%2BE%3D&st=2020-03-02T16%3A54%3A16Z&se=2020-03-03T01%3A04%3A16Z&sp=r',
#   'azureml-logs/process_info.json': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168288_485f9fd8/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=aqh%2FU7Gy2u6OaT3jO2m4hmrxdlt6LLd0v4xQOGxewWA%3D&st=2020-03-02T16%3A54%3A16Z&se=2020-03-03T01%3A04%3A16Z&sp=r',
#   'azureml-logs/process_status.json': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168288_485f9fd8/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=loCVC5ovKNaohV2niKHBQpak80VoaY5ESB1kuu0hdXA%3D&st=2020-03-02T16%3A54%3A16Z&se=2020-03-03T01%3A04%3A16Z&sp=r',
#   'logs/azureml/138_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168288_485f9fd8/logs/azureml/138_azureml.log?sv=2019-02-02&sr=b&sig=e9SPug9Esl3DV8oVJA%2B69Qtoz6hbuAbkM8KiF9rzC1Y%3D&st=2020-03-02T16%3A54%3A15Z&se=2020-03-03T01%3A04%3A15Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168288_485f9fd8/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=J6YFde8uxi%2F0a1L9FKJ4zi7K831WOiFIzfikYKYiP1Q%3D&st=2020-03-02T16%3A54%3A16Z&se=2020-03-03T01%3A04%3A16Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168288_485f9fd8/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=9%2FjBM75ozBSold5YpBYm66u00U30gdsUUCaTYBeRUZ8%3D&st=2020-03-02T16%3A54%3A16Z&se=2020-03-03T01%3A04%3A16Z&sp=r'}}

# %% [markdown]
# ## Register or download a model

# %%
from azureml.core import Model
from azureml.core.resource_configuration import ResourceConfiguration

model = run.register_model(model_name='tf-dnn-mnist', 
                           model_path='outputs/model',
                           model_framework=Model.Framework.TENSORFLOW,
                           model_framework_version='1.13.0',
                           resource_configuration=ResourceConfiguration(cpu=1, memory_in_gb=0.5))

# %% [markdown]
# ## Distributed training

# %%
# Create a model folder in the current directory
os.makedirs('./model', exist_ok=True)

for f in run.get_file_names():
    if f.startswith('outputs/model'):
        output_file_path = os.path.join('./model', f.split('/')[-1])
        print('Downloading from {} to {} ...'.format(f, output_file_path))
        run.download_file(name=f, output_file_path=output_file_path)
# Out:
# Downloading from outputs/model/checkpoint to ./model/checkpoint ...
# Downloading from outputs/model/mnist-tf.model.data-00000-of-00001 to ./model/mnist-tf.model.data-00000-of-00001 ...
# Downloading from outputs/model/mnist-tf.model.index to ./model/mnist-tf.model.index ...
# Downloading from outputs/model/mnist-tf.model.meta to ./model/mnist-tf.model.meta ...

# %%
from azureml.core.runconfig import MpiConfiguration
from azureml.train.dnn import TensorFlow

# Tensorflow constructor
estimator= TensorFlow(source_directory=script_folder,
                      compute_target=compute_target,
                      script_params=script_params,
                      entry_script='tf_mnist.py',
                      node_count=2,
                      process_count_per_node=1,
                      distributed_training=MpiConfiguration(),
                      framework_version='1.13',
                      use_gpu=True,
                      pip_packages=['azureml-dataprep[pandas,fuse]'])

# %%
run = exp.submit(estimator)
run.wait_for_completion(show_output=True)
# Out:
# RunId: tf-mnist_1583168659_e8ea87f6
# Web View: https://ml.azure.com/experiments/tf-mnist/runs/tf-mnist_1583168659_e8ea87f6?wsid=/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourcegroups/sqlserverkonferenz2020/workspaces/mldemo
#
# Streaming azureml-logs/55_azureml-execution-tvmps_8b84303de576a570cdf02cfc0d7b5eeebe6e10edb473ed2d0c756e344633687e_d.txt
# ========================================================================================================================
#
# 2020-03-02T17:07:19Z Starting output-watcher...
# 2020-03-02T17:07:19Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_1d5e282518217ede461ec1726f1f4557
# f7277927d38a: Pulling fs layer
# 8d3eac894db4: Pulling fs layer
# edf72af6d627: Pulling fs layer
# 3e4f86211d23: Pulling fs layer
# d6e9603ff777: Pulling fs layer
# 5cad422780e2: Pulling fs layer
# 8130687c8acb: Pulling fs layer
# c11e9246d621: Pulling fs layer
# 0dfae24cbbd9: Pulling fs layer
# 5cad422780e2: Waiting
# 8130687c8acb: Waiting
# 3e4f86211d23: Waiting
# 0bb049a6d391: Pulling fs layer
# 22a53069998a: Pulling fs layer
# 0bb049a6d391: Waiting
# c11e9246d621: Waiting
# 0dfae24cbbd9: Waiting
# 22a53069998a: Waiting
# db550b9db251: Pulling fs layer
# 10a826755d7e: Pulling fs layer
# 457c96476eac: Pulling fs layer
# e2d7418d62ad: Pulling fs layer
# a0d6fa61e0b7: Pulling fs layer
# 93f75153ba2d: Pulling fs layer
# 435aa96ed16e: Pulling fs layer
# d360acd15cf6: Pulling fs layer
# 10a826755d7e: Waiting
# 457c96476eac: Waiting
# b9d304610f0f: Pulling fs layer
# 51d07a5ef961: Pulling fs layer
# 435aa96ed16e: Waiting
# 93f75153ba2d: Waiting
# d360acd15cf6: Waiting
# a4f78ec21a8d: Pulling fs layer
# f366159de4d2: Pulling fs layer
# 51d07a5ef961: Waiting
# e2d7418d62ad: Waiting
# b9d304610f0f: Waiting
# edf72af6d627: Verifying Checksum
# edf72af6d627: Download complete
# 8d3eac894db4: Verifying Checksum
# 8d3eac894db4: Download complete
# 3e4f86211d23: Verifying Checksum
# 3e4f86211d23: Download complete
# d6e9603ff777: Verifying Checksum
# d6e9603ff777: Download complete
# 8130687c8acb: Verifying Checksum
# 8130687c8acb: Download complete
# f7277927d38a: Verifying Checksum
# f7277927d38a: Download complete
#
# Streaming azureml-logs/65_job_prep-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job preparation. Current time:2020-03-02T17:07:23.887850
# Extracting the control code.
# Creating directory: azureml-logs/
# Retrieving project from snapshot: e338b394-0a87-4bb9-a6f8-f8c06248241c
# Starting the daemon thread to refresh tokens in background for process with pid = 84
# Starting project file download.
# Finished project file download.
# Download from datastores if requested.
# Download or mount from datasets if requested.
# Job preparation is complete. Current time:2020-03-02T17:07:27.177932
#
# Streaming azureml-logs/65_job_prep-tvmps_8b84303de576a570cdf02cfc0d7b5eeebe6e10edb473ed2d0c756e344633687e_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/libtinfo.so.5: no version information available (required by bash)
# Not a master node. Exiting.
#
# Streaming azureml-logs/70_driver_log_0.txt
# ==========================================
#
# bash: /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/libtinfo.so.5: no version information available (required by bash)
# This is an MPI job. Rank:0
# Initialize DatasetContextManager.
# Starting the daemon thread to refresh tokens in background for process with pid = 168
# Set Dataset mnist's target path to /tmp/tmp6xka6ynr
# Enter __enter__ of DatasetContextManager
# Processing 'mnist'
# Processing dataset FileDataset
# {
#   "source": [
#     "http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz",
#     "http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz",
#     "http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz",
#     "http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "c1dc2de4-45ab-4877-add2-fa43e8cd8db5",
#     "name": "mnist dataset",
#     "version": 1,
#     "description": "training and test dataset",
#     "workspace": "Workspace.create(name='mldemo', subscription_id='b208dd3b-2592-4e14-a626-cd6941369193', resource_group='sqlserverkonferenz2020')"
#   }
# }
# Mounting mnist to /tmp/tmp6xka6ynr
# Mounted mnist to /tmp/tmp6xka6ynr
# Exit __enter__ of DatasetContextManager
# Entering Run History Context Manager.
# Preparing to call script [ tf_mnist.py ] with arguments: ['--data-folder', '$mnist', '--batch-size', '50', '--first-layer-neurons', '300', '--second-layer-neurons', '100', '--learning-rate', '0.01']
# After variable expansion, calling script [ tf_mnist.py ] with arguments: ['--data-folder', '/tmp/tmp6xka6ynr', '--batch-size', '50', '--first-layer-neurons', '300', '--second-layer-neurons', '100', '--learning-rate', '0.01']
#
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# TensorFlow version: 1.13.1
# Data folder: /tmp/tmp6xka6ynr
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)
# WARNING - From tf_mnist.py:55: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING - From /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2020-03-02 17:09:34.368989: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-03-02 17:09:34.494519: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x4f931b0 executing computations on platform CUDA. Devices:
# 2020-03-02 17:09:34.494611: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-03-02 17:09:34.496632: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2596990000 Hz
# 2020-03-02 17:09:34.497381: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x50ae260 executing computations on platform Host. Devices:
# 2020-03-02 17:09:34.497437: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-03-02 17:09:34.497606: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 266f:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.11GiB
# 2020-03-02 17:09:34.497672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-03-02 17:09:34.500084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-02 17:09:34.500141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-03-02 17:09:34.500176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-03-02 17:09:34.500279: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10804 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 266f:00:00.0, compute capability: 3.7)
# 2020-03-02 17:09:35.137783: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# 0 -- Training accuracy: 0.82 Validation accuracy: 0.904
# 1 -- Training accuracy: 0.88 Validation accuracy: 0.9201
# 2 -- Training accuracy: 0.94 Validation accuracy: 0.9306
# 3 -- Training accuracy: 0.98 Validation accuracy: 0.9384
# 4 -- Training accuracy: 0.98 Validation accuracy: 0.9437
# 5 -- Training accuracy: 0.94 Validation accuracy: 0.9475
# 6 -- Training accuracy: 0.98 Validation accuracy: 0.9507
# 7 -- Training accuracy: 0.92 Validation accuracy: 0.9524
# 8 -- Training accuracy: 1.0 Validation accuracy: 0.9565
# 9 -- Training accuracy: 1.0 Validation accuracy: 0.9584
# 10 -- Training accuracy: 0.94 Validation accuracy: 0.9606
# 11 -- Training accuracy: 0.98 Validation accuracy: 0.9622
# 12 -- Training accuracy: 1.0 Validation accuracy: 0.9632
# 13 -- Training accuracy: 0.98 Validation accuracy: 0.9662
# 14 -- Training accuracy: 0.96 Validation accuracy: 0.9661
# 15 -- Training accuracy: 1.0 Validation accuracy: 0.9683
# 16 -- Training accuracy: 0.98 Validation accuracy: 0.9689
# 17 -- Training accuracy: 1.0 Validation accuracy: 0.9703
# 18 -- Training accuracy: 1.0 Validation accuracy: 0.971
# 19 -- Training accuracy: 0.98 Validation accuracy: 0.972
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.2569255828857422 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 168
# Enter __exit__ of DatasetContextManager
# Unmounting /tmp/tmp6xka6ynr.
# Finishing unmounting /tmp/tmp6xka6ynr.
# Exit __exit__ of DatasetContextManager
#
# Streaming azureml-logs/75_job_post-tvmps_8b84303de576a570cdf02cfc0d7b5eeebe6e10edb473ed2d0c756e344633687e_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_87bf8b18f50c3819153ad5fad9efbcd9/lib/libtinfo.so.5: no version information available (required by bash)
#
# Execution Summary
# =================
# RunId: tf-mnist_1583168659_e8ea87f6
# Web View: https://ml.azure.com/experiments/tf-mnist/runs/tf-mnist_1583168659_e8ea87f6?wsid=/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourcegroups/sqlserverkonferenz2020/workspaces/mldemo
# {'runId': 'tf-mnist_1583168659_e8ea87f6',
#  'target': 'gpucluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-03-02T17:07:15.554792Z',
#  'endTimeUtc': '2020-03-02T17:10:35.794201Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'fe26bcec-e9a8-496a-a0e2-093c947ecb55',
#   'azureml.git.repository_uri': 'https://github.com/marcelfranke/sqlserverkonferenz.git',
#   'mlflow.source.git.repoURL': 'https://github.com/marcelfranke/sqlserverkonferenz.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': 'cd62b64c4786bfdafcce452be272413cf5cc82d7',
#   'mlflow.source.git.commit': 'cd62b64c4786bfdafcce452be272413cf5cc82d7',
#   'azureml.git.dirty': 'False',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': 'c1dc2de4-45ab-4877-add2-fa43e8cd8db5'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'mnist', 'mechanism': 'Mount'}}],
#  'runDefinition': {'script': 'tf_mnist.py',
#   'useAbsolutePath': False,
#   'arguments': ['--data-folder',
#    'DatasetConsumptionConfig:mnist',
#    '--batch-size',
#    '50',
#    '--first-layer-neurons',
#    '300',
#    '--second-layer-neurons',
#    '100',
#    '--learning-rate',
#    '0.01'],
#   'sourceDirectoryDataStore': 'workspaceblobstore',
#   'framework': 'Python',
#   'communicator': 'Mpi',
#   'target': 'gpucluster',
#   'dataReferences': {'workspaceblobstore': {'dataStoreName': 'workspaceblobstore',
#     'mode': 'Mount',
#     'pathOnDataStore': None,
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'data': {'mnist': {'dataLocation': {'dataset': {'id': 'c1dc2de4-45ab-4877-add2-fa43e8cd8db5'},
#      'dataPath': None},
#     'createOutputDirectories': False,
#     'mechanism': 'Mount',
#     'environmentVariableName': 'mnist',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 2,
#   'environment': {'name': 'Experiment tf-mnist Environment',
#    'version': 'Autosave_2020-03-01T20:24:31Z_26d07de6',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-dataprep[pandas,fuse]',
#         'azureml-defaults',
#         'tensorflow-gpu==1.13.1',
#         'horovod==0.16.1']}],
#      'name': 'azureml_87bf8b18f50c3819153ad5fad9efbcd9'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/base-gpu:intelmpi2018.3-cuda10.0-cudnn7-ubuntu16.04',
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': False},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': 2},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_8b84303de576a570cdf02cfc0d7b5eeebe6e10edb473ed2d0c756e344633687e_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/55_azureml-execution-tvmps_8b84303de576a570cdf02cfc0d7b5eeebe6e10edb473ed2d0c756e344633687e_d.txt?sv=2019-02-02&sr=b&sig=Yfey38OxztHok9iDG%2BbkH6QbT7l%2FhGooL39FXwUhCLw%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/55_azureml-execution-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt?sv=2019-02-02&sr=b&sig=rXxy28CLjh8vfTaJhnoO3HqyWFSwYwK%2Fe6M%2FaVB%2Fsf0%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_8b84303de576a570cdf02cfc0d7b5eeebe6e10edb473ed2d0c756e344633687e_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/65_job_prep-tvmps_8b84303de576a570cdf02cfc0d7b5eeebe6e10edb473ed2d0c756e344633687e_d.txt?sv=2019-02-02&sr=b&sig=UavOMp4o26PqEPWpW2kd3oDbUBBU63x0JwrZpMQQGl8%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/65_job_prep-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt?sv=2019-02-02&sr=b&sig=dIdrFFRHCWWUkUTpMOVUvjxaNC9gJhtUEWNNFRVmaJU%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/70_driver_log_0.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/70_driver_log_0.txt?sv=2019-02-02&sr=b&sig=rJh4d2lTmYIAb4ya98lhfQ%2BhjeMedmSFeDVDjysBf7s%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/70_driver_log_1.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/70_driver_log_1.txt?sv=2019-02-02&sr=b&sig=6zG2C4mM1pkD8UIyXqIdkEgFbhBcDqyilIEg%2Fkk4KDk%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/70_mpi_log.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/70_mpi_log.txt?sv=2019-02-02&sr=b&sig=RoORfFfq%2Bc%2FHLkvcGTYVUB1oxx17EivpUlgXIIFHsIc%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_8b84303de576a570cdf02cfc0d7b5eeebe6e10edb473ed2d0c756e344633687e_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/75_job_post-tvmps_8b84303de576a570cdf02cfc0d7b5eeebe6e10edb473ed2d0c756e344633687e_d.txt?sv=2019-02-02&sr=b&sig=v1Ll2PfAFl5JSbJdrrwkoE8Ip80f5dplXyEtvTM8kxs%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/75_job_post-tvmps_ea36fda09dbae355eb997b39512516fa8949d6833e06ffe56359d4a0fe1a0299_d.txt?sv=2019-02-02&sr=b&sig=lWEKq8%2FFIOueWbO28MfNVUYVC9svkSdQdm34UAIr57w%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/process_info.json': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=ItWBG83aHPvgYWJ1uPHjKML1AM1f8VU%2BLDTgRb5phxE%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'azureml-logs/process_status.json': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=vkG9zQjkzPQqg89lue5cc%2FimykiaJT%2FowQ9F8TPvZDk%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'logs/azureml/0_168_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/logs/azureml/0_168_azureml.log?sv=2019-02-02&sr=b&sig=OFUJQWbMMEce5sv2QuDGyJ4mTJem9OK%2Ft4jdbDyPooQ%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'logs/azureml/1_116_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/logs/azureml/1_116_azureml.log?sv=2019-02-02&sr=b&sig=qDk%2BeRPkHFo9%2F2yJxTnyqJpVuIbxlDuFSZARdgorgGg%3D&st=2020-03-02T17%3A00%3A37Z&se=2020-03-03T01%3A10%3A37Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=aVmgZMu%2BPCHMm6gcobyptLg4%2BujD1DJ1fTQ9qORGyKI%3D&st=2020-03-02T17%3A00%3A38Z&se=2020-03-03T01%3A10%3A38Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.tf-mnist_1583168659_e8ea87f6/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=RzQ5HkfrOQ7c7mBf5GotPaNNBsHavm7Ab1g3Kk4eoQM%3D&st=2020-03-02T17%3A00%3A38Z&se=2020-03-03T01%3A10%3A38Z&sp=r'}}
