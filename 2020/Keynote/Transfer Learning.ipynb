# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# # Transfer learning sample
# * Train model
# * Build Image
# * Create IoT Edge deployment JSON
# * Deploy Model

# %% [markdown]
# ![title](./images/VAIDKe2e.png)

# %%
# For prod
#!pip install azureml-core azureml-contrib-iot azure-mgmt-containerregistry azure-cli
#!az extension add --name azure-cli-iot-ext

# %%
import os
print(os.__file__)
# Out:
# /anaconda/envs/azureml_py36/lib/python3.6/os.py

# %%
# Check core SDK version number
import azureml.core as azcore

print("SDK version:", azcore.VERSION)
# Out:
# SDK version: 1.0.85

# %% [markdown]
# ### Create a Workspace

# %%
#Initialize Workspace 
from azureml.core import Workspace

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# mldemo
# sqlserverkonferenz2020
# northeurope
# b208dd3b-2592-4e14-a626-cd6941369193

# %% [markdown]
# ### Create Experiment
# Experiment is a logical container in an Azure ML Workspace. It hosts run records which can include run metrics and output artifacts from your experiments.

# %%
experiment_name = 'realtime_object_detection'

from azureml.core import Experiment
exp = Experiment(workspace = ws, name = experiment_name)

# %% [markdown]
# ## Get data
# ### Option 1: Upload data files into datastore
# Every workspace comes with a default datastore (and you can register more) which is backed by the Azure blob storage account associated with the workspace. We can use it to transfer data from local to the cloud, and access it from the compute target.

# %%
# get the default datastore
ds = ws.get_default_datastore()
print(ds.name, ds.datastore_type, ds.account_name, ds.container_name)
# Out:
# workspaceblobstore AzureBlob mldemo9068087925 azureml-blobstore-33f5cdb9-d04e-4f11-bb7a-263b2736aab0

# %%
data_path = experiment_name + '_training_data'
ds.upload(src_dir='data/images', target_path=data_path, overwrite=True)
# Out:
# Uploading an estimated of 133 files
# Uploading data/images/bikes/IMG_20181207_154255.jpg
# Uploading data/images/bikes/IMG_20181207_154300.jpg
# Uploading data/images/bikes/IMG_20181207_154307.jpg
# Uploading data/images/bikes/IMG_20181207_154321.jpg
# Uploading data/images/bikes/IMG_20181207_154324.jpg
# Uploading data/images/bikes/IMG_20181207_154327.jpg
# Uploading data/images/bikes/IMG_20181207_154330.jpg
# Uploading data/images/bikes/IMG_20181207_154331.jpg
# Uploading data/images/bikes/IMG_20181207_154334.jpg
# Uploading data/images/bikes/IMG_20181207_154335.jpg
# Uploading data/images/bikes/IMG_20181207_154337.jpg
# Uploading data/images/bikes/IMG_20181207_154338.jpg
# Uploading data/images/bikes/IMG_20181207_154339.jpg
# Uploading data/images/bikes/IMG_20181207_154340.jpg
# Uploading data/images/bikes/IMG_20181207_154341.jpg
# Uploading data/images/bikes/IMG_20181207_154391.jpg
# Uploading data/images/bikes/IMG_20181207_154392.jpg
# Uploading data/images/bikes/IMG_20181207_154393.jpg
# Uploading data/images/bikes/IMG_20181207_154539.jpg
# Uploading data/images/bikes/IMG_20181207_154542.jpg
# Uploading data/images/bikes/IMG_20181207_154545.jpg
# Uploading data/images/bikes/IMG_20181207_154546.jpg
# Uploading data/images/bikes/IMG_20181207_154551.jpg
# Uploading data/images/bikes/IMG_20181207_154552.jpg
# Uploading data/images/bikes/IMG_20181207_154553.jpg
# Uploading data/images/bikes/IMG_20181207_154555.jpg
# Uploading data/images/bikes/IMG_20181207_154556.jpg
# Uploading data/images/bikes/IMG_20181207_154812.jpg
# Uploading data/images/bikes/IMG_20181207_154814.jpg
# Uploading data/images/bikes/IMG_20181207_154815.jpg
# Uploading data/images/bikes/IMG_20181207_154817.jpg
# Uploading data/images/bikes/IMG_20181207_154818.jpg
# Uploaded data/images/bikes/IMG_20181207_154814.jpg, 1 files out of an estimated total of 133
# Uploading data/images/bikes/IMG_20181207_154820.jpg
# Uploaded data/images/bikes/IMG_20181207_154331.jpg, 2 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154649.jpg
# Uploaded data/images/bikes/IMG_20181207_154324.jpg, 3 files out of an estimated total of 133
# Uploaded data/images/bikes/IMG_20181207_154300.jpg, 4 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154652.jpg
# Uploading data/images/cars/IMG_20181207_154654.jpg
# Uploaded data/images/bikes/IMG_20181207_154391.jpg, 5 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154656.jpg
# Uploaded data/images/bikes/IMG_20181207_154339.jpg, 6 files out of an estimated total of 133
# Uploaded data/images/bikes/IMG_20181207_154539.jpg, 7 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154659.jpg
# Uploading data/images/cars/IMG_20181207_154671.jpg
# Uploaded data/images/bikes/IMG_20181207_154327.jpg, 8 files out of an estimated total of 133
# Uploaded data/images/bikes/IMG_20181207_154393.jpg, 9 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154672.jpg
# Uploading data/images/cars/IMG_20181207_154673.jpg
# Uploaded data/images/cars/IMG_20181207_154659.jpg, 10 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154701.jpg
# Uploaded data/images/cars/IMG_20181207_154649.jpg, 11 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154704.jpg
# Uploaded data/images/cars/IMG_20181207_154656.jpg, 12 files out of an estimated total of 133
# Uploaded data/images/cars/IMG_20181207_154671.jpg, 13 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154706.jpg
# Uploading data/images/cars/IMG_20181207_154708.jpg
# Uploaded data/images/cars/IMG_20181207_154652.jpg, 14 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154710.jpg
# Uploaded data/images/cars/IMG_20181207_154672.jpg, 15 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154712.jpg
# Uploaded data/images/bikes/IMG_20181207_154815.jpg, 16 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154714.jpg
# Uploaded data/images/cars/IMG_20181207_154673.jpg, 17 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154724.jpg
# Uploaded data/images/cars/IMG_20181207_154654.jpg, 18 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154726.jpg
# Uploaded data/images/cars/IMG_20181207_154704.jpg, 19 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154732.jpg
# Uploaded data/images/cars/IMG_20181207_154701.jpg, 20 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154735.jpg
# Uploaded data/images/bikes/IMG_20181207_154392.jpg, 21 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154737.jpg
# Uploaded data/images/cars/IMG_20181207_154708.jpg, 22 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154739.jpg
# Uploaded data/images/bikes/IMG_20181207_154330.jpg, 23 files out of an estimated total of 133
# Uploaded data/images/bikes/IMG_20181207_154818.jpg, 24 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154741.jpg
# Uploading data/images/cars/IMG_20181207_154743.jpg
# Uploaded data/images/bikes/IMG_20181207_154820.jpg, 25 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154746.jpg
# Uploaded data/images/cars/IMG_20181207_154706.jpg, 26 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154748.jpg
# Uploaded data/images/bikes/IMG_20181207_154255.jpg, 27 files out of an estimated total of 133
# Uploaded data/images/cars/IMG_20181207_154712.jpg, 28 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154750.jpg
# Uploading data/images/cars/IMG_20181207_154752.jpg
# Uploaded data/images/bikes/IMG_20181207_154817.jpg, 29 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154756.jpg
# Uploaded data/images/bikes/IMG_20181207_154307.jpg, 30 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154758.jpg
# Uploaded data/images/cars/IMG_20181207_154714.jpg, 31 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154800.jpg
# Uploaded data/images/bikes/IMG_20181207_154321.jpg, 32 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154802.jpg
# Uploaded data/images/bikes/IMG_20181207_154556.jpg, 33 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154804.jpg
# Uploaded data/images/cars/IMG_20181207_154710.jpg, 34 files out of an estimated total of 133
# Uploaded data/images/bikes/IMG_20181207_154341.jpg, 35 files out of an estimated total of 133
# Uploading data/images/cars/IMG_20181207_154805.jpg
# Uploading data/images/cars/IMG_20181207_154806.jpg
# Uploaded data/images/cars/IMG_20181207_154737.jpg, 36 files out of an estimated total of 133
# Uploaded data/images/bikes/IMG_20181207_154552.jpg, 37 files out of an estimated total of 133
# Uploaded data/images/bikes/IMG_20181207_154337.jpg, 38 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154349.jpg
# Uploading data/images/people/IMG_20181207_154350.jpg
# Uploaded data/images/bikes/IMG_20181207_154335.jpg, 39 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154357.jpg
# Uploaded data/images/bikes/IMG_20181207_154546.jpg, 40 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154358.jpg
# Uploaded data/images/bikes/IMG_20181207_154334.jpg, 41 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154361.jpg
# Uploaded data/images/bikes/IMG_20181207_154338.jpg, 42 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154362.jpg
# Uploading data/images/people/IMG_20181207_154363.jpg
# Uploaded data/images/cars/IMG_20181207_154724.jpg, 43 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154364.jpg
# Uploaded data/images/bikes/IMG_20181207_154545.jpg, 44 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154365.jpg
# Uploaded data/images/bikes/IMG_20181207_154555.jpg, 45 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154367.jpg
# Uploaded data/images/cars/IMG_20181207_154735.jpg, 46 files out of an estimated total of 133
# Uploaded data/images/cars/IMG_20181207_154802.jpg, 47 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154375.jpg
# Uploaded data/images/bikes/IMG_20181207_154553.jpg, 48 files out of an estimated total of 133
# Uploaded data/images/bikes/IMG_20181207_154542.jpg, 49 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154376.jpg
# Uploading data/images/people/IMG_20181207_154377.jpg
# Uploaded data/images/cars/IMG_20181207_154741.jpg, 50 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154378.jpg
# Uploaded data/images/bikes/IMG_20181207_154340.jpg, 51 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154391.jpg
# Uploaded data/images/cars/IMG_20181207_154732.jpg, 52 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154392.jpg
# Uploading data/images/people/IMG_20181207_154393.jpg
# Uploaded data/images/cars/IMG_20181207_154756.jpg, 53 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154400.jpg
# Uploaded data/images/cars/IMG_20181207_154726.jpg, 54 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154401.jpg
# Uploaded data/images/cars/IMG_20181207_154743.jpg, 55 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154408.jpg
# Uploaded data/images/cars/IMG_20181207_154746.jpg, 56 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154418.jpg
# Uploaded data/images/cars/IMG_20181207_154758.jpg, 57 files out of an estimated total of 133
# Uploaded data/images/bikes/IMG_20181207_154812.jpg, 58 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154512.jpg
# Uploaded data/images/cars/IMG_20181207_154804.jpg, 59 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154514.jpg
# Uploading data/images/people/IMG_20181207_154522.jpg
# Uploaded data/images/cars/IMG_20181207_154806.jpg, 60 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154524.jpg
# Uploaded data/images/people/IMG_20181207_154363.jpg, 61 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154525.jpg
# Uploaded data/images/cars/IMG_20181207_154752.jpg, 62 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154527.jpg
# Uploaded data/images/cars/IMG_20181207_154739.jpg, 63 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154828.jpg
# Uploaded data/images/people/IMG_20181207_154357.jpg, 64 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154830.jpg
# Uploaded data/images/bikes/IMG_20181207_154551.jpg, 65 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154832.jpg
# Uploaded data/images/cars/IMG_20181207_154748.jpg, 66 files out of an estimated total of 133
# Uploaded data/images/cars/IMG_20181207_154800.jpg, 67 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154833.jpg
# Uploaded data/images/people/IMG_20181207_154362.jpg, 68 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154835.jpg
# Uploaded data/images/cars/IMG_20181207_154805.jpg, 69 files out of an estimated total of 133
# Uploading data/images/people/IMG_20181207_154837.jpg
# Uploaded data/images/people/IMG_20181207_154365.jpg, 70 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154919.jpg
# Uploading data/images/trucks/IMG_20181207_154922.jpg
# Uploaded data/images/people/IMG_20181207_154350.jpg, 71 files out of an estimated total of 133
# Uploaded data/images/people/IMG_20181207_154349.jpg, 72 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154925.jpg
# Uploaded data/images/cars/IMG_20181207_154750.jpg, 73 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154927.jpg
# Uploaded data/images/people/IMG_20181207_154364.jpg, 74 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154929.jpg
# Uploaded data/images/people/IMG_20181207_154358.jpg, 75 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154931.jpg
# Uploading data/images/trucks/IMG_20181207_154933.jpg
# Uploaded data/images/people/IMG_20181207_154377.jpg, 76 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154936.jpg
# Uploaded data/images/people/IMG_20181207_154378.jpg, 77 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154938.jpg
# Uploaded data/images/people/IMG_20181207_154376.jpg, 78 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154940.jpg
# Uploaded data/images/people/IMG_20181207_154400.jpg, 79 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154945.jpg
# Uploaded data/images/people/IMG_20181207_154361.jpg, 80 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154947.jpg
# Uploaded data/images/people/IMG_20181207_154367.jpg, 81 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154949.jpg
# Uploaded data/images/people/IMG_20181207_154401.jpg, 82 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154951.jpg
# Uploaded data/images/people/IMG_20181207_154512.jpg, 83 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154953.jpg
# Uploaded data/images/people/IMG_20181207_154527.jpg, 84 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154955.jpg
# Uploaded data/images/people/IMG_20181207_154391.jpg, 85 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154958.jpg
# Uploaded data/images/people/IMG_20181207_154837.jpg, 86 files out of an estimated total of 133
# Uploaded data/images/people/IMG_20181207_154392.jpg, 87 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154961.jpg
# Uploading data/images/trucks/IMG_20181207_154962.jpg
# Uploaded data/images/trucks/IMG_20181207_154927.jpg, 88 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154963.jpg
# Uploaded data/images/people/IMG_20181207_154418.jpg, 89 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154964.jpg
# Uploaded data/images/people/IMG_20181207_154408.jpg, 90 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154965.jpg
# Uploaded data/images/trucks/IMG_20181207_154931.jpg, 91 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154966.jpg
# Uploaded data/images/people/IMG_20181207_154525.jpg, 92 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154967.jpg
# Uploaded data/images/trucks/IMG_20181207_154933.jpg, 93 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154968.jpg
# Uploaded data/images/trucks/IMG_20181207_154922.jpg, 94 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154969.jpg
# Uploaded data/images/trucks/IMG_20181207_154938.jpg, 95 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154970.jpg
# Uploaded data/images/people/IMG_20181207_154524.jpg, 96 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154971.jpg
# Uploaded data/images/people/IMG_20181207_154832.jpg, 97 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154991.jpg
# Uploaded data/images/trucks/IMG_20181207_154936.jpg, 98 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154992.jpg
# Uploaded data/images/trucks/IMG_20181207_154919.jpg, 99 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_154993.jpg
# Uploaded data/images/trucks/IMG_20181207_154925.jpg, 100 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_155000.jpg
# Uploaded data/images/people/IMG_20181207_154393.jpg, 101 files out of an estimated total of 133
# Uploading data/images/trucks/IMG_20181207_155002.jpg
# Uploaded data/images/people/IMG_20181207_154830.jpg, 102 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154929.jpg, 103 files out of an estimated total of 133
# Uploaded data/images/people/IMG_20181207_154514.jpg, 104 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154961.jpg, 105 files out of an estimated total of 133
# Uploaded data/images/people/IMG_20181207_154835.jpg, 106 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154963.jpg, 107 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154947.jpg, 108 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154965.jpg, 109 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154968.jpg, 110 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154945.jpg, 111 files out of an estimated total of 133
# Uploaded data/images/people/IMG_20181207_154522.jpg, 112 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154964.jpg, 113 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154940.jpg, 114 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154962.jpg, 115 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154966.jpg, 116 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154970.jpg, 117 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154969.jpg, 118 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154951.jpg, 119 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154967.jpg, 120 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154953.jpg, 121 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154971.jpg, 122 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154955.jpg, 123 files out of an estimated total of 133
# Uploaded data/images/people/IMG_20181207_154833.jpg, 124 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154949.jpg, 125 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_155000.jpg, 126 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154958.jpg, 127 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154993.jpg, 128 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_155002.jpg, 129 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154992.jpg, 130 files out of an estimated total of 133
# Uploaded data/images/people/IMG_20181207_154375.jpg, 131 files out of an estimated total of 133
# Uploaded data/images/people/IMG_20181207_154828.jpg, 132 files out of an estimated total of 133
# Uploaded data/images/trucks/IMG_20181207_154991.jpg, 133 files out of an estimated total of 133
# Uploaded 133 files
# $AZUREML_DATAREFERENCE_72621bbbed1c4ab78fcf36c73ce5d48a

# %% [markdown]
# ### Configure for using ACI
# Linux-based ACI is available in West US, East US, West Europe, North Europe, West US 2, Southeast Asia, Australia East, East US 2, and Central US regions.  See details [here](https://docs.microsoft.com/en-us/azure/container-instances/container-instances-quotas#region-availability)

# %%
from azureml.core.runconfig import DataReferenceConfiguration
dr = DataReferenceConfiguration(datastore_name=ds.name, 
                   path_on_datastore=data_path, 
                   mode='download', # download files from datastore to compute target
                   overwrite=True)

# %% [markdown]
# Set the system to build a conda environment based on the run configuration. Once the environment is built, and if you don't change your dependencies, it will be reused in subsequent runs.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# choose a name for your cluster
cluster_name = "gpucluster"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_NC6', max_nodes=4)

    # create the cluster
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True)

# Use the 'status' property to get a detailed status for the current AmlCompute. 
print(compute_target.status.serialize())
# Out:
# Found existing compute target.
# {'currentNodeCount': 1, 'targetNodeCount': 0, 'nodeStateCounts': {'preparingNodeCount': 0, 'runningNodeCount': 0, 'idleNodeCount': 0, 'unusableNodeCount': 0, 'leavingNodeCount': 1, 'preemptedNodeCount': 0}, 'allocationState': 'Resizing', 'allocationStateTransitionTime': '2020-03-02T18:45:08.061000+00:00', 'errors': None, 'creationTime': '2020-03-01T20:19:05.537092+00:00', 'modifiedTime': '2020-03-01T20:19:21.483613+00:00', 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 4, 'nodeIdleTimeBeforeScaleDown': 'PT120S'}, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_NC6'}

# %%
from azureml.core.runconfig import RunConfiguration, DEFAULT_CPU_IMAGE
from azureml.core.conda_dependencies import CondaDependencies

# create a new runconfig object
run_config = RunConfiguration(framework = "python")

# Set compute target
run_config.target = compute_target.name

# set the data reference of the run configuration
run_config.data_references = {ds.name: dr}

# enable Docker 
run_config.environment.docker.enabled = True

# set Docker base image to the default CPU-based image
run_config.environment.docker.base_image = DEFAULT_CPU_IMAGE

# use conda_dependencies.yml to create a conda environment in the Docker image for execution
run_config.environment.python.user_managed_dependencies = False

# auto-prepare the Docker image when used for execution (if it is not already prepared)
run_config.auto_prepare_environment = True

# specify CondaDependencies obj
run_config.environment.python.conda_dependencies = CondaDependencies.create(conda_packages=['tensorflow==1.8.0'])
# Out:
# 'auto_prepare_environment' is deprecated and unused. It will be removed in a future release.
# 'auto_prepare_environment' is deprecated and unused. It will be removed in a future release.

# %% [markdown]
# ### Submit the Experiment
# Submit script to run in the Docker image in the remote VM. If you run this for the first time, the system will download the base image, layer in packages specified in the conda_dependencies.yml file on top of the base image, create a container and then execute the script in the container.

# %%
from azureml.core import Run
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory = './scripts', script = 'retrain.py', run_config = run_config, 
                      # pass the datastore reference as a parameter to the training script
                      arguments=['--image_dir', str(ds.as_download()),
                                 '--architecture', 'mobilenet_1.0_224',
                                 '--output_graph', 'outputs/retrained_graph.pb',
                                 '--output_labels', 'outputs/output_labels.txt',
                                 '--model_download_url', 'https://raw.githubusercontent.com/rakelkar/models/master/model_output/',
                                 '--model_file_name', 'imagenet_2_frozen.pb'
                                ])
run = exp.submit(config=src)

# %%
run
# Out:
# Run(Experiment: realtime_object_detection,
# Id: realtime_object_detection_1583174949_8abb6f3c,
# Type: azureml.scriptrun,
# Status: Starting)

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: realtime_object_detection_1583174949_8abb6f3c
# Web View: https://ml.azure.com/experiments/realtime_object_detection/runs/realtime_object_detection_1583174949_8abb6f3c?wsid=/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourcegroups/sqlserverkonferenz2020/workspaces/mldemo
#
# Streaming azureml-logs/55_azureml-execution-tvmps_82ef165f16c72eec9a1bae5a04e9d87a7037798569b41344a86e044c331211dd_d.txt
# ========================================================================================================================
#
# 2020-03-02T18:53:42Z Starting output-watcher...
# 2020-03-02T18:53:42Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_4e6f302af538c639cbeed755d36b8100
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# 42404d6b1a6e: Pulling fs layer
# adc7f911b430: Pulling fs layer
# be28a08ea885: Pulling fs layer
# 4b345f36c3d8: Pulling fs layer
# 6bc8175400d1: Pulling fs layer
# 634911e84d12: Pulling fs layer
# 4e38f320d0d4: Waiting
# b0a763e8ee03: Waiting
# 11917a028ca4: Waiting
# a6c378d11cbf: Waiting
# 6cc007ad9140: Waiting
# 6c1698a608f3: Waiting
# 42404d6b1a6e: Waiting
# adc7f911b430: Waiting
# be28a08ea885: Waiting
# 4b345f36c3d8: Waiting
# 8269c605f3f1: Waiting
# 6504d449e70c: Waiting
# 6bc8175400d1: Waiting
# 634911e84d12: Waiting
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# 9b0d3db6dc03: Verifying Checksum
# 9b0d3db6dc03: Download complete
# 8269c605f3f1: Download complete
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# 6c1698a608f3: Verifying Checksum
# 6c1698a608f3: Download complete
# 42404d6b1a6e: Verifying Checksum
# 42404d6b1a6e: Download complete
# be28a08ea885: Verifying Checksum
# be28a08ea885: Download complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# 4b345f36c3d8: Verifying Checksum
# 4b345f36c3d8: Download complete
# adc7f911b430: Download complete
# 634911e84d12: Download complete
# a1298f4ce990: Pull complete
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Pull complete
# 6bc8175400d1: Download complete
# 6504d449e70c: Pull complete
# 4e38f320d0d4: Pull complete
# b0a763e8ee03: Pull complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# 42404d6b1a6e: Pull complete
# adc7f911b430: Pull complete
# be28a08ea885: Pull complete
# 4b345f36c3d8: Pull complete
# 6bc8175400d1: Pull complete
# 634911e84d12: Pull complete
# Digest: sha256:5438aea47ea9fcc719b180225efd8ccdfcb78759b7cad46ee10b3f1266d895ad
# Status: Downloaded newer image for mldemof2348786.azurecr.io/azureml/azureml_4e6f302af538c639cbeed755d36b8100:latest
# 5e4dfa86c9bf43624c18231b7dfa171ccd909b1dc8f1850c41871face0e19969
# 2020/03/02 18:54:16 Version: 3.0.01150.0001 Branch: master Commit: d0a02aae
# 2020/03/02 18:54:17 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/03/02 18:54:17 sshd runtime has already been installed in the container
# ssh-keygen: /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# ssh-keygen: /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# bash: /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/libtinfo.so.5: no version information available (required by bash)
#
# Streaming azureml-logs/65_job_prep-tvmps_82ef165f16c72eec9a1bae5a04e9d87a7037798569b41344a86e044c331211dd_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job preparation. Current time:2020-03-02T18:54:23.777133
# Extracting the control code.
# Creating directory: azureml-logs/
# Retrieving project from snapshot: bad52fad-7f82-45f1-bc56-3165094d4b5b
# Starting the daemon thread to refresh tokens in background for process with pid = 99
# Starting project file download.
# Finished project file download.
# Download from datastores if requested.
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154255.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154300.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154307.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154321.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154324.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154327.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154330.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154331.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154334.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154335.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154337.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154338.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154339.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154340.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154341.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154391.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154392.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154393.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154539.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154542.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154545.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154546.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154551.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154552.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154553.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154555.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154556.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154812.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154814.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154815.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154817.jpg
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154818.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154331.jpg, 1 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/bikes/IMG_20181207_154820.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154393.jpg, 2 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154649.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154340.jpg, 3 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154652.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154555.jpg, 4 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154307.jpg, 5 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154654.jpg
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154656.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154300.jpg, 6 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154659.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154324.jpg, 7 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154671.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154330.jpg, 8 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154672.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154337.jpg, 9 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154673.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154335.jpg, 10 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154327.jpg, 11 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154701.jpg
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154704.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154339.jpg, 12 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154706.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154334.jpg, 13 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154708.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154672.jpg, 14 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154710.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154255.jpg, 15 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154712.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154649.jpg, 16 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154714.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154321.jpg, 17 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154724.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154701.jpg, 18 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154704.jpg, 19 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154539.jpg, 20 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154726.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154652.jpg, 21 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154545.jpg, 22 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154732.jpg
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154735.jpg
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154737.jpg
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154739.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154708.jpg, 23 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154741.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154673.jpg, 24 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154743.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154542.jpg, 25 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154746.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154656.jpg, 26 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154546.jpg, 27 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154748.jpg
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154750.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154710.jpg, 28 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154752.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154659.jpg, 29 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154756.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154391.jpg, 30 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154392.jpg, 31 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154758.jpg
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154800.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154817.jpg, 32 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154802.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154338.jpg, 33 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154804.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154737.jpg, 34 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154341.jpg, 35 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154805.jpg
# Downloading realtime_object_detection_training_data/cars/IMG_20181207_154806.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154815.jpg, 36 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154349.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154671.jpg, 37 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154350.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154735.jpg, 38 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154357.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154741.jpg, 39 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154358.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154739.jpg, 40 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154812.jpg, 41 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154820.jpg, 42 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154361.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154362.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154363.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154556.jpg, 43 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154364.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154654.jpg, 44 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154365.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154756.jpg, 45 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154758.jpg, 46 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154367.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154752.jpg, 47 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154551.jpg, 48 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154375.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154376.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154800.jpg, 49 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154743.jpg, 50 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154805.jpg, 51 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154377.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154746.jpg, 52 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154804.jpg, 53 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154378.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154391.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154392.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154393.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154400.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154802.jpg, 54 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154401.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154706.jpg, 55 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154408.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154552.jpg, 56 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154814.jpg, 57 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154357.jpg, 58 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154418.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154806.jpg, 59 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154350.jpg, 60 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154512.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154514.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154712.jpg, 61 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154522.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154524.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154525.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154349.jpg, 62 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154748.jpg, 63 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154527.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154828.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154750.jpg, 64 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154830.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154818.jpg, 65 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154832.jpg
# Downloaded realtime_object_detection_training_data/bikes/IMG_20181207_154553.jpg, 66 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154362.jpg, 67 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154358.jpg, 68 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154833.jpg
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154835.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154377.jpg, 69 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/people/IMG_20181207_154837.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154363.jpg, 70 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154919.jpg
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154922.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154364.jpg, 71 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154925.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154375.jpg, 72 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154927.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154365.jpg, 73 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154367.jpg, 74 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154929.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154400.jpg, 75 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154931.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154361.jpg, 76 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154933.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154376.jpg, 77 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154936.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154724.jpg, 78 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154938.jpg
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154940.jpg
# Downloaded realtime_object_detection_training_data/trucks/IMG_20181207_154919.jpg, 79 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154945.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154378.jpg, 80 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154732.jpg, 81 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154947.jpg
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154949.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154392.jpg, 82 files out of an estimated total of 133
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154391.jpg, 83 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154951.jpg
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154953.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154512.jpg, 84 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154955.jpg
# Downloaded realtime_object_detection_training_data/cars/IMG_20181207_154714.jpg, 85 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154958.jpg
# Downloaded realtime_object_detection_training_data/trucks/IMG_20181207_154927.jpg, 86 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154961.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154401.jpg, 87 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154962.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154408.jpg, 88 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154963.jpg
# Downloaded realtime_object_detection_training_data/trucks/IMG_20181207_154925.jpg, 89 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154964.jpg
# Downloaded realtime_object_detection_training_data/people/IMG_20181207_154393.jpg, 90 files out of an estimated total of 133
# Downloading realtime_object_detection_training_data/trucks/IMG_20181207_154965.jpg
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# bash: /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/libtinfo.so.5: no version information available (required by bash)
# Starting the daemon thread to refresh tokens in background for process with pid = 186
# Entering Run History Context Manager.
# Preparing to call script [ retrain.py ] with arguments: ['--image_dir', '/mnt/batch/tasks/shared/LS_root/jobs/mldemo/9b17458d5ea9428c8111dfbd6d0e146e/realtime_object_detection_1583174949_8abb6f3c/mounts/workspaceblobstore/azureml/realtime_object_detection_1583174949_8abb6f3c/workspaceblobstore/realtime_object_detection_training_data', '--architecture', 'mobilenet_1.0_224', '--output_graph', 'outputs/retrained_graph.pb', '--output_labels', 'outputs/output_labels.txt', '--model_download_url', 'https://raw.githubusercontent.com/rakelkar/models/master/model_output/', '--model_file_name', 'imagenet_2_frozen.pb']
# After variable expansion, calling script [ retrain.py ] with arguments: ['--image_dir', '/mnt/batch/tasks/shared/LS_root/jobs/mldemo/9b17458d5ea9428c8111dfbd6d0e146e/realtime_object_detection_1583174949_8abb6f3c/mounts/workspaceblobstore/azureml/realtime_object_detection_1583174949_8abb6f3c/workspaceblobstore/realtime_object_detection_training_data', '--architecture', 'mobilenet_1.0_224', '--output_graph', 'outputs/retrained_graph.pb', '--output_labels', 'outputs/output_labels.txt', '--model_download_url', 'https://raw.githubusercontent.com/rakelkar/models/master/model_output/', '--model_file_name', 'imagenet_2_frozen.pb']
#
# /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# https://raw.githubusercontent.com/rakelkar/models/master/model_output/mobilenet_v1_1.0_224_frozen.tgz
# /tmp/imagenet
# /tmp/imagenet/mobilenet_v1_1.0_224_frozen.tgz
#
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 0.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 1.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 2.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 3.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 4.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 5.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 6.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 7.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 8.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 9.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 10.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 11.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 12.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 13.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 14.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 15.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 16.9%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.0%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.1%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.2%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.3%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.4%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.5%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.6%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.7%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.8%
# >> Downloading mobilenet_v1_1.0_224_frozen.tgz 17.9%
# ...
# INFO:tensorflow:2020-03-02 18:58:00.447019: Step 3700: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:00.447222: Step 3700: Cross entropy = 0.000279
# INFO:tensorflow:2020-03-02 18:58:00.491666: Step 3700: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:00.947816: Step 3710: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:00.948043: Step 3710: Cross entropy = 0.000223
# INFO:tensorflow:2020-03-02 18:58:00.992971: Step 3710: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:01.448146: Step 3720: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:01.448424: Step 3720: Cross entropy = 0.000178
# INFO:tensorflow:2020-03-02 18:58:01.493926: Step 3720: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:01.950617: Step 3730: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:01.950832: Step 3730: Cross entropy = 0.000260
# INFO:tensorflow:2020-03-02 18:58:01.996213: Step 3730: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:02.464830: Step 3740: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:02.465042: Step 3740: Cross entropy = 0.000132
# INFO:tensorflow:2020-03-02 18:58:02.512452: Step 3740: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:02.967262: Step 3750: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:02.967458: Step 3750: Cross entropy = 0.000257
# INFO:tensorflow:2020-03-02 18:58:03.012718: Step 3750: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:03.483342: Step 3760: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:03.483548: Step 3760: Cross entropy = 0.000342
# INFO:tensorflow:2020-03-02 18:58:03.528772: Step 3760: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:03.987010: Step 3770: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:03.987228: Step 3770: Cross entropy = 0.000238
# INFO:tensorflow:2020-03-02 18:58:04.032609: Step 3770: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:04.491493: Step 3780: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:04.491701: Step 3780: Cross entropy = 0.000188
# INFO:tensorflow:2020-03-02 18:58:04.537046: Step 3780: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:04.996233: Step 3790: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:04.996451: Step 3790: Cross entropy = 0.000184
# INFO:tensorflow:2020-03-02 18:58:05.042899: Step 3790: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:05.497114: Step 3800: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:05.497311: Step 3800: Cross entropy = 0.000189
# INFO:tensorflow:2020-03-02 18:58:05.541406: Step 3800: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:05.994565: Step 3810: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:05.994775: Step 3810: Cross entropy = 0.000196
# INFO:tensorflow:2020-03-02 18:58:06.039118: Step 3810: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:06.504169: Step 3820: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:06.504371: Step 3820: Cross entropy = 0.000182
# INFO:tensorflow:2020-03-02 18:58:06.549459: Step 3820: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:07.005094: Step 3830: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:07.005310: Step 3830: Cross entropy = 0.000144
# INFO:tensorflow:2020-03-02 18:58:07.050618: Step 3830: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:07.507169: Step 3840: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:07.507374: Step 3840: Cross entropy = 0.000236
# INFO:tensorflow:2020-03-02 18:58:07.552622: Step 3840: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:08.011138: Step 3850: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:08.011327: Step 3850: Cross entropy = 0.000109
# INFO:tensorflow:2020-03-02 18:58:08.057423: Step 3850: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:08.517147: Step 3860: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:08.517354: Step 3860: Cross entropy = 0.000332
# INFO:tensorflow:2020-03-02 18:58:08.562544: Step 3860: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:09.015869: Step 3870: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:09.016079: Step 3870: Cross entropy = 0.000225
# INFO:tensorflow:2020-03-02 18:58:09.061293: Step 3870: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:09.520813: Step 3880: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:09.521022: Step 3880: Cross entropy = 0.000128
# INFO:tensorflow:2020-03-02 18:58:09.566575: Step 3880: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:10.025902: Step 3890: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:10.026116: Step 3890: Cross entropy = 0.000458
# INFO:tensorflow:2020-03-02 18:58:10.070877: Step 3890: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:10.531448: Step 3900: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:10.531645: Step 3900: Cross entropy = 0.000123
# INFO:tensorflow:2020-03-02 18:58:10.577015: Step 3900: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:11.031787: Step 3910: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:11.032002: Step 3910: Cross entropy = 0.000141
# INFO:tensorflow:2020-03-02 18:58:11.077098: Step 3910: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:11.540729: Step 3920: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:11.540933: Step 3920: Cross entropy = 0.000245
# INFO:tensorflow:2020-03-02 18:58:11.586102: Step 3920: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:12.046373: Step 3930: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:12.046607: Step 3930: Cross entropy = 0.000142
# INFO:tensorflow:2020-03-02 18:58:12.091658: Step 3930: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:12.557312: Step 3940: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:12.557514: Step 3940: Cross entropy = 0.000144
# INFO:tensorflow:2020-03-02 18:58:12.602757: Step 3940: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:13.062342: Step 3950: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:13.062596: Step 3950: Cross entropy = 0.000184
# INFO:tensorflow:2020-03-02 18:58:13.110385: Step 3950: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:13.567361: Step 3960: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:13.567560: Step 3960: Cross entropy = 0.000264
# INFO:tensorflow:2020-03-02 18:58:13.612763: Step 3960: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:14.069331: Step 3970: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:14.069552: Step 3970: Cross entropy = 0.000159
# INFO:tensorflow:2020-03-02 18:58:14.114473: Step 3970: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:14.571808: Step 3980: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:14.572008: Step 3980: Cross entropy = 0.000258
# INFO:tensorflow:2020-03-02 18:58:14.616566: Step 3980: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:15.079404: Step 3990: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:15.079616: Step 3990: Cross entropy = 0.000146
# INFO:tensorflow:2020-03-02 18:58:15.124156: Step 3990: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2020-03-02 18:58:15.538554: Step 3999: Train accuracy = 100.0%
# INFO:tensorflow:2020-03-02 18:58:15.538763: Step 3999: Cross entropy = 0.000151
# INFO:tensorflow:2020-03-02 18:58:15.583679: Step 3999: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:Final test accuracy = 100.0% (N=6)
# INFO:tensorflow:Froze 2 variables.
# Converted 2 variables to const ops.
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 1 items cleaning up...
# Cleanup took 0.0006184577941894531 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 186
#
# Streaming azureml-logs/75_job_post-tvmps_82ef165f16c72eec9a1bae5a04e9d87a7037798569b41344a86e044c331211dd_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_31bf638353952672e89fbfb46007260c/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job release. Current time:2020-03-02T18:58:21.440576
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 439
# Job release is complete. Current time:2020-03-02T18:58:23.976679
#
# Execution Summary
# =================
# RunId: realtime_object_detection_1583174949_8abb6f3c
# Web View: https://ml.azure.com/experiments/realtime_object_detection/runs/realtime_object_detection_1583174949_8abb6f3c?wsid=/subscriptions/b208dd3b-2592-4e14-a626-cd6941369193/resourcegroups/sqlserverkonferenz2020/workspaces/mldemo
# {'runId': 'realtime_object_detection_1583174949_8abb6f3c',
#  'target': 'gpucluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-03-02T18:53:43.353819Z',
#  'endTimeUtc': '2020-03-02T18:58:39.46745Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '3fcdf363-c1f0-41a2-b9de-539a36fe4264',
#   'azureml.git.repository_uri': 'https://github.com/marcelfranke/sqlserverkonferenz.git',
#   'mlflow.source.git.repoURL': 'https://github.com/marcelfranke/sqlserverkonferenz.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': 'cd62b64c4786bfdafcce452be272413cf5cc82d7',
#   'mlflow.source.git.commit': 'cd62b64c4786bfdafcce452be272413cf5cc82d7',
#   'azureml.git.dirty': 'True',
#   'AzureML.DerivedImageName': 'azureml/azureml_4e6f302af538c639cbeed755d36b8100',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'runDefinition': {'script': 'retrain.py',
#   'useAbsolutePath': False,
#   'arguments': ['--image_dir',
#    '$AZUREML_DATAREFERENCE_workspaceblobstore',
#    '--architecture',
#    'mobilenet_1.0_224',
#    '--output_graph',
#    'outputs/retrained_graph.pb',
#    '--output_labels',
#    'outputs/output_labels.txt',
#    '--model_download_url',
#    'https://raw.githubusercontent.com/rakelkar/models/master/model_output/',
#    '--model_file_name',
#    'imagenet_2_frozen.pb'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'gpucluster',
#   'dataReferences': {'workspaceblobstore': {'dataStoreName': 'workspaceblobstore',
#     'mode': 'Download',
#     'pathOnDataStore': 'realtime_object_detection_training_data',
#     'pathOnCompute': None,
#     'overwrite': True}},
#   'data': {},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'environment': {'name': 'Experiment realtime_object_detection Environment',
#    'version': 'Autosave_2020-03-02T17:31:44Z_8fc220f0',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults']},
#       'tensorflow==1.8.0'],
#      'name': 'azureml_31bf638353952672e89fbfb46007260c'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04',
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_82ef165f16c72eec9a1bae5a04e9d87a7037798569b41344a86e044c331211dd_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.realtime_object_detection_1583174949_8abb6f3c/azureml-logs/55_azureml-execution-tvmps_82ef165f16c72eec9a1bae5a04e9d87a7037798569b41344a86e044c331211dd_d.txt?sv=2019-02-02&sr=b&sig=rtbLFvCWwqKVGV7WqL%2BJlZUtWGYbpKbDx8S5xH%2F3vaY%3D&st=2020-03-02T18%3A48%3A41Z&se=2020-03-03T02%3A58%3A41Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_82ef165f16c72eec9a1bae5a04e9d87a7037798569b41344a86e044c331211dd_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.realtime_object_detection_1583174949_8abb6f3c/azureml-logs/65_job_prep-tvmps_82ef165f16c72eec9a1bae5a04e9d87a7037798569b41344a86e044c331211dd_d.txt?sv=2019-02-02&sr=b&sig=hLn8LrzictQoKRj%2FxkPG9p0iNI0U2UtE4js4eWoe5Es%3D&st=2020-03-02T18%3A48%3A41Z&se=2020-03-03T02%3A58%3A41Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.realtime_object_detection_1583174949_8abb6f3c/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=3N5yhJ1WOsuzPywW%2Bn9RWVDZNR7YYxImeCI%2BBQhR7vg%3D&st=2020-03-02T18%3A48%3A41Z&se=2020-03-03T02%3A58%3A41Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_82ef165f16c72eec9a1bae5a04e9d87a7037798569b41344a86e044c331211dd_d.txt': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.realtime_object_detection_1583174949_8abb6f3c/azureml-logs/75_job_post-tvmps_82ef165f16c72eec9a1bae5a04e9d87a7037798569b41344a86e044c331211dd_d.txt?sv=2019-02-02&sr=b&sig=y5OeJjJtO%2FIRlbGgKmglAfrfmW1Yu6mk7cHpi%2FUzszM%3D&st=2020-03-02T18%3A48%3A41Z&se=2020-03-03T02%3A58%3A41Z&sp=r',
#   'azureml-logs/process_info.json': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.realtime_object_detection_1583174949_8abb6f3c/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=J05tuWUV7z%2B8q4KEzNUwSMe75d%2BcKTWeU9CaSk2QhAw%3D&st=2020-03-02T18%3A48%3A41Z&se=2020-03-03T02%3A58%3A41Z&sp=r',
#   'azureml-logs/process_status.json': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.realtime_object_detection_1583174949_8abb6f3c/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=TrR%2B5aAYWoY2UzBqD22VrqYSxKzTvY4WbnsfElyCdtw%3D&st=2020-03-02T18%3A48%3A41Z&se=2020-03-03T02%3A58%3A41Z&sp=r',
#   'logs/azureml/186_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.realtime_object_detection_1583174949_8abb6f3c/logs/azureml/186_azureml.log?sv=2019-02-02&sr=b&sig=c9iqyjymsiWZkC91F4QTeRlaoAOPA5L1O135gRkwtz0%3D&st=2020-03-02T18%3A48%3A42Z&se=2020-03-03T02%3A58%3A42Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.realtime_object_detection_1583174949_8abb6f3c/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=8q8NeNo1UVcBY7CoIopbDmIU6g4MyJNckHnJnPdrHTo%3D&st=2020-03-02T18%3A48%3A42Z&se=2020-03-03T02%3A58%3A42Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://mldemo9068087925.blob.core.windows.net/azureml/ExperimentRun/dcid.realtime_object_detection_1583174949_8abb6f3c/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=fM8AzFj01S8cSUKKG3NXXzfQM3C8DFCyEOA6Erpr8vw%3D&st=2020-03-02T18%3A48%3A42Z&se=2020-03-03T02%3A58%3A42Z&sp=r'}}

# %% [markdown]
# ## Get the trained model

# %%
trained_model_path = "models/mobilenet-orig/"

# %%
# Download the retrained model and the labels locally
run.download_file(name = 'outputs/retrained_graph.pb', output_file_path = trained_model_path)
run.download_file(name = 'outputs/output_labels.txt', output_file_path = trained_model_path)

# %% [markdown]
# ![title](./images/Image.png)

# %% [markdown]
# ### NVIDIA config file
# This step uses the trained model from your local folder in the Notebooks shell.
# There are three files (i) the __model_name.pb__ file, (ii) the __lables_names.txt__ and (iii) __deepstream-engine-library_config.json__, in this folder.
#
# This deepstream-engine-library_config file is used by the camera when loading the model into the inference engine.
#
# __key fields are:__
# 1. Engine: This is the network used by the model
#    * 0: MobileNet
#    * 1: MobileNet-SSD
#    * 2: SqueezeNet
# 2. NetworkIO:
#    * 0: CPU (default)
#    * 1: DSP
# 3. Runtime: this is the HW option to use for inferencing
#    * 0: CPU
#    * 1: DSP
#    * 2: GPU
# ConfThreshold: This is the threshold for when the bounding boxes are shown or inferencing results are shown on screen.

# %%
nvidia_config_file = trained_model_path + "/deepstream-engine-library_config.json"

# %%
# %%writefile $nvidia_config_file
# {
# "Engine":0,
# "NetworkIO":1,
# "ScaleWidth":224,
# "ScaleHeight":224,
# "PixelNorm":127.5,
# "BlueMean":104,
# "GreenMean":117,
# "RedMean":123,
# "TargetFPS":30,
# "ConfThreshold":0.0,
# "DLC_NAME":"model.dlc",
# "LABELS_NAME":"output_labels.txt",
# "InputLayers":"input:0",
# "OutputLayers":["final_result"],
# "ResultLayers":["final_result:0"],
# "Runtime":1
# }
# Out:
# Overwriting models/mobilenet-orig//deepstream-engine-library_config.json

# %%
from azureml.core.model import Model

model = Model.register(model_path = trained_model_path,
                      model_name = "NVIDIADeepStream_model",
                      tags = {"data": "Imagenet", "model": "object_detection", "type": "imagenet"},
                      description = "Retrained model based on MobileNet",
                      workspace = ws)
# Out:
# Registering model NVIDIADeepStream_model

# %%
from azureml.contrib.iot.model_converters import SnpeConverter

# submit a compile request
compile_request = SnpeConverter.convert_tf_model(
    ws,
    source_model=model,
    input_node="input",
    input_dims="1,224,224,3",
    outputs_nodes = ["final_result"],
    allow_unconsumed_nodes = True)
print(compile_request._operation_id)
# Out:
# 71aa2732-d3b8-4501-af1f-5d088ec77198

# %%
# wait for the request to complete
compile_request.wait_for_completion(show_output=True)
# Out:
# Running....................
# Succeeded
# Operation 71aa2732-d3b8-4501-af1f-5d088ec77198 completed, operation state "Succeeded"
# sas url to download model conversion logs https://mldemo9068087925.blob.core.windows.net/azureml/LocalUpload/72d18a077ccd4ba78b03547818366d32/conversion_log?sv=2019-02-02&sr=b&sig=EvdRh3Mc1plbs7s4PsDc4hXRIceMYeQZnidSWT%2FyZ2w%3D&st=2020-03-02T19%3A18%3A26Z&se=2020-03-03T03%3A28%3A26Z&sp=r
# [2020-03-02 19:26:45Z]: Starting model conversion process
# [2020-03-02 19:26:45Z]: Downloading model for conversion
# [2020-03-02 19:26:51Z]: Converting model
# [2020-03-02 19:26:58Z]: converter std: Executing python /snpe-1.25.0/bin/x86_64-linux-clang/snpe-tensorflow-to-dlc --graph /tmp/zm2jfugn.5kt/input/mobilenet-orig/retrained_graph.pb -i input 1,224,224,3 --dlc /tmp/zm2jfugn.5kt/output/model.dlc --out_node final_result --allow_unconsumed_nodes in /app
# [2020-03-02 19:26:58Z]: converter std: Stream stdout is True
# [2020-03-02 19:26:58Z]: converter std: 2020-03-02 19:26:52.649443: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# [2020-03-02 19:26:58Z]: converter std: 2020-03-02 19:26:52.656372: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2394450000 Hz
# [2020-03-02 19:26:58Z]: converter std: 2020-03-02 19:26:52.657573: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x46e78b0 executing computations on platform Host. Devices:
# [2020-03-02 19:26:58Z]: converter std: 2020-03-02 19:26:52.657605: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# [2020-03-02 19:26:58Z]: converter std: 2020-03-02 19:26:53,163 - 404 - WARNING - ERROR_TF_FALLBACK_TO_ONDEMAND_EVALUATION: Unable to resolve operation output shapes in single pass. Using on-demand evaluation!
# [2020-03-02 19:26:58Z]: converter std: Execution took 0.001355s for ['python', '/snpe-1.25.0/bin/x86_64-linux-clang/snpe-tensorflow-to-dlc', '--graph', '/tmp/zm2jfugn.5kt/input/mobilenet-orig/retrained_graph.pb', '-i', u'input', u'1,224,224,3', '--dlc', '/tmp/zm2jfugn.5kt/output/model.dlc', '--out_node', u'final_result', '--allow_unconsumed_nodes'] in /app
# [2020-03-02 19:26:58Z]: Uploading conversion results
# [2020-03-02 19:27:00Z]: Conversion completed with result Success
# True

# %%
# Get converted model
converted_model = compile_request.result
print(converted_model.name, converted_model.url, converted_model.version, converted_model.id, converted_model.created_time)
# Out:
# NVIDIADeepStream_model.1.dlc aml://asset/c0fd1de40c594df0adde325d5cbfa75d 1 NVIDIADeepStream_model.1.dlc:1 2020-03-02 19:28:24.420573+00:00

# %%
from azureml.core.image import Image
from azureml.contrib.iot import IotContainerImage
print ('We will create an image for you now ...')
image_config = IotContainerImage.image_configuration(
                                 #architecture="arm32v7",
                                 architecture="amd64",
                                 execution_script="main.py", 
                                 dependencies=["camera.py","iot.py","ipcprovider.py","utility.py", "frame_iterators.py"],
                                 docker_file="Dockerfile", 
                                 tags = ["mobilenet"],
                                 description = "Retrained model based on MobileNet")
image = Image.create(name = "nvidiadeepstreamobjdet",
                     # this is the model object 
                     models = [converted_model],
                     image_config = image_config, 
                     workspace = ws)
image.wait_for_creation(show_output = True)
# Out:
# We will create an image for you now ...
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: Image class has been deprecated and will be removed in a future release. Please migrate to using Environments. https://docs.microsoft.com/en-us/azure/machine-learning/how-to-use-environments
#   from ipykernel import kernelapp as app
# Creating image
# Running......................................................................................................................................
# Succeeded
# Image creation operation finished for image nvidiadeepstreamobjdet:1, operation "Succeeded"

# %%
image
# Out:
# IotContainerImage(workspace=Workspace.create(name='mldemo', subscription_id='b208dd3b-2592-4e14-a626-cd6941369193', resource_group='sqlserverkonferenz2020'), name=nvidiadeepstreamobjdet, id=nvidiadeepstreamobjdet:1, tags={}, properties={}, version=1)

# %% [markdown]
# ![title](./images/Deploy.png)

# %% [markdown]
# #### Setup the details for the IoT Hub.
# You can use the configuration from an existing IoT Hub if you have one setup.

# %%
# Parameter list

# Pick a name for what you want to call the module you deploy to the camera
module_name = "visionsample"

# Resource group in Azure 
resource_group_name= ws.resource_group
iot_rg="vaidk_"+resource_group_name # or use the existing RG

# Azure region where your services will be provisioned
iot_location="north europe" # or use the existing location

# Azure IoT Hub name
iot_hub_name="iothub-"+ ws.get_details()["name"] # or use the name of an existing IoT Hub

# Pick a name for your camera
iot_device_id="vadik_"+ ws.get_details()["name"] # or use the existing device ID from IoT Hub configuration

# Pick a name for the deployment configuration
iot_deployment_id="demovaidk" #

# %%
# Getting your container details
container_reg = ws.get_details()["containerRegistry"]
reg_name=container_reg.split("/")[-1]
container_url = "\"" + image.image_location + "\","
subscription_id = ws.subscription_id
print('{}'.format(image.image_location))
print('{}'.format(reg_name))
print('{}'.format(subscription_id))
from azure.mgmt.containerregistry import ContainerRegistryManagementClient
from azure.mgmt import containerregistry
client = ContainerRegistryManagementClient(ws._auth,subscription_id)
result= client.registries.list_credentials(resource_group_name, reg_name, custom_headers=None, raw=False)
username = result.username
password = result.passwords[0].value

# %% [markdown]
# ### Deployment file
# This is the deployment.json file that you will use to deploy your model.  Please see the other sample notebooks on using this file to deploy the new model you created.

# %%
file = open('./deployment-template.json')
contents = file.read()
contents = contents.replace('__MODULE_NAME', module_name)
contents = contents.replace('__REGISTRY_NAME', reg_name)
contents = contents.replace('__REGISTRY_USER_NAME', username)
contents = contents.replace('__REGISTRY_PASSWORD', password)
contents = contents.replace('__REGISTRY_IMAGE_LOCATION', image.image_location)
with open('./deployment.json', 'wt', encoding='utf-8') as output_file:
    output_file.write(contents)

# %% [markdown]
# ### Option 1: Push this updated deployment manifest to an existing IoT Hub

# %%
# !az login

# %%
# set azure subscription
with open ('setsub','w+') as command1:
    command1.write('az account set --subscription ' + subscription_id )
    command1.close()
# !sh setsub

# %%
# confirm the default azure account before pushing IoT Edge deployment
# !az account show

# %%
print("Pushing deployment to IoT Edge device")

# %%
print ("Set the deployment") 
# !az iot edge set-modules --device-id $iot_device_id --hub-name $iot_hub_name --content deployment.json

# %% [markdown]
# ### Option 2: Create a new Azure IoT Hub
# __SKIP__ if you have already pushed to an existing IoT Hub

# %%
# print ( 'We will create your HUB now')

# with open ('setsub','w+') as command1:
#     command1.write('az account set --subscription ' + subscription_id )
#     command1.close()
# !sh setsub

# with open ('create','w+') as command2:
#     regcommand="\n echo Installing Extension ... \naz extension add --name azure-cli-iot-ext \n"+ "\n echo CREATING RG "+iot_rg+"... \naz group create --name "+ iot_rg +" --location "+ iot_location+ "\n" +"\n echo CREATING HUB "+iot_hub_name+"... \naz iot hub create --name "+ iot_hub_name + " --resource-group "+ iot_rg +" --sku S1"
#     command2.write(regcommand +"\n echo CREATING DEVICE ID "+iot_device_id+"... \n az iot hub device-identity create --device-id "+ iot_device_id + " --hub-name " +  iot_hub_name +" --edge-enabled")
#     command2.close()
# !sh create

# with open ('deploy','w+')as command3:
#     createcommand="\n echo DEPLOYING "+iot_deployment_id+" ... \naz iot edge deployment create --deployment-id \"" + iot_deployment_id + "\" --content \"deployment.json\" --hub-name \"" +  iot_hub_name +"\" --target-condition \"deviceId='"+iot_device_id+"'\" --priority 1"
#     command3.write(createcommand)
#     command3.close()
# !sh deploy

# with open ('details','w+')as command4:
#     get_string="\n echo THIS IS YOUR CONNECTION STRING ... \naz iot hub device-identity show-connection-string --device-id  \"" + iot_device_id + "\" --hub-name \"" +  iot_hub_name+"\""
#     command4.write(get_string)
#     command4.close()

# %%
# !sh details
# print("COPY THIS CONNECTION STRING FOR YOUR DEVICE")

# %% [markdown]
# #### Now use this conenction string on your Vision AI Dev Kit during the device OOBE & initialization
